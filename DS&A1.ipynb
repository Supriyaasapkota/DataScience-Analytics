# %% [markdown]
# <a href="https://colab.research.google.com/github/Supriyaasapkota/DataScience-Analytics/blob/main/DS%26A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
pd.DataFrame({"Bob":["I liked it","It was awful."],"Sue":["Pretty good","Bland."]})
# Out:
#              Bob          Sue
# 0     I liked it  Pretty good
# 1  It was awful.       Bland.

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'],
              'Sue': ['Pretty good.', 'Bland.']},
             index=['Product A', 'Product B'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %%
df=pd.read_csv("drivers.csv")

# %%
df.shape
# Out:
# (150, 12)

# %%
df.head(6)
# Out:
#   driver_id first_name  last_name   hire_date termination_date license_number  \
# 0  DRV00001   Jennifer  Hernandez  2014-10-31              NaN    DL673510887
# 1  DRV00002    William     Martin  2020-10-02              NaN    DL128955006
# 2  DRV00003    Charles  Hernandez  2021-09-21              NaN    DL523076025
# 3  DRV00004    Barbara      Brown  2013-09-08              NaN    DL735540030
# 4  DRV00005       Mary   Martinez  2018-12-02              NaN    DL706011277
# 5  DRV00006     Robert     Taylor  2019-04-04              NaN    DL811890569
#
#   license_state date_of_birth   home_terminal employment_status cdl_class  \
# 0            WA    1973-11-07          Denver            Active         A
# 1            GA    1976-11-03        Columbus            Active         A
# 2            NC    1970-04-06  Salt Lake City            Active         A
# 3            WA    1995-02-06          Denver            Active         A
# ...

# %%
df.driver_id #column lai herna
# Out:
# 0      DRV00001
# 1      DRV00002
# 2      DRV00003
# 3      DRV00004
# 4      DRV00005
#          ...
# 145    DRV00146
# 146    DRV00147
# 147    DRV00148
# 148    DRV00149
# 149    DRV00150
# Name: driver_id, Length: 150, dtype: object

# %%
df["employment_status"]
# Out:
# 0      Active
# 1      Active
# 2      Active
# 3      Active
# 4      Active
#         ...
# 145    Active
# 146    Active
# 147    Active
# 148    Active
# 149    Active
# Name: employment_status, Length: 150, dtype: object

# %%
df["first_name"][1]
# Out:
# 'William'

# %%
df.iloc[0] #iloc le chai location denote
# Out:
# driver_id               DRV00001
# first_name              Jennifer
# last_name              Hernandez
# hire_date             2014-10-31
# termination_date             NaN
# license_number       DL673510887
# license_state                 WA
# date_of_birth         1973-11-07
# home_terminal             Denver
# employment_status         Active
# cdl_class                      A
# years_experience               3
# Name: 0, dtype: object

# %%
df.iloc[1:7]
# Out:
#   driver_id first_name  last_name   hire_date termination_date license_number  \
# 1  DRV00002    William     Martin  2020-10-02              NaN    DL128955006
# 2  DRV00003    Charles  Hernandez  2021-09-21              NaN    DL523076025
# 3  DRV00004    Barbara      Brown  2013-09-08              NaN    DL735540030
# 4  DRV00005       Mary   Martinez  2018-12-02              NaN    DL706011277
# 5  DRV00006     Robert     Taylor  2019-04-04              NaN    DL811890569
# 6  DRV00007      James   Martinez  2019-07-02       2021-05-17    DL129100607
#
#   license_state date_of_birth   home_terminal employment_status cdl_class  \
# 1            GA    1976-11-03        Columbus            Active         A
# 2            NC    1970-04-06  Salt Lake City            Active         A
# 3            WA    1995-02-06          Denver            Active         A
# 4            AZ    1960-07-15         Chicago            Active         A
# ...

# %%
df.first_name=="William"
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: first_name, Length: 150, dtype: bool

# %%
df.last_name=="Hernandez"
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: last_name, Length: 150, dtype: bool

# %%
df.loc[df.first_name=="Sarah"]
# Out:
#     driver_id first_name last_name   hire_date termination_date  \
# 9    DRV00010      Sarah  Gonzalez  2020-11-08              NaN
# 69   DRV00070      Sarah  Anderson  2014-12-15              NaN
# 125  DRV00126      Sarah   Jackson  2012-10-14              NaN
# 138  DRV00139      Sarah     Davis  2014-08-27              NaN
#
#     license_number license_state date_of_birth home_terminal  \
# 9      DL560219456            WA    1974-05-26   Minneapolis
# 69     DL275842194            PA    1974-07-02  Indianapolis
# 125    DL389998761            TX    1981-02-15   Minneapolis
# 138    DL363598427            MN    1986-02-05     Charlotte
#
#     employment_status cdl_class  years_experience
# 9              Active         A                23
# 69             Active         A                16
# 125            Active         A                25
# 138            Active         A                14

# %%
df.loc[(df.first_name=="Mary") | (df.last_name=="Martinez")]
# Out:
#     driver_id first_name last_name   hire_date termination_date  \
# 4    DRV00005       Mary  Martinez  2018-12-02              NaN
# 6    DRV00007      James  Martinez  2019-07-02       2021-05-17
# 10   DRV00011    Michael  Martinez  2014-06-01              NaN
# 19   DRV00020     Joseph  Martinez  2019-07-21              NaN
# 23   DRV00024    Barbara  Martinez  2021-09-15              NaN
# 24   DRV00025    Jessica  Martinez  2015-09-17              NaN
# 38   DRV00039     Thomas  Martinez  2013-06-29              NaN
# 42   DRV00043       Mary  Williams  2017-04-06              NaN
# 44   DRV00045     Thomas  Martinez  2018-11-20              NaN
# 54   DRV00055       Mary  Anderson  2012-07-01              NaN
# 93   DRV00094       Mary    Taylor  2017-11-29              NaN
# 99   DRV00100   Jennifer  Martinez  2019-01-04              NaN
# 112  DRV00113       Mary  Williams  2017-09-30              NaN
# 120  DRV00121       Mary    Miller  2012-07-20              NaN
# ...

# %%
df.hire_date.dtype #date lai chai object datatype
# Out:
# dtype('O')

# %%
df.years_experience.dtype
# Out:
# dtype('int64')
